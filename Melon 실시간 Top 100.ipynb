# %%
from selenium import webdriver
import re

# %%
driver = webdriver.Chrome()
driver.get("https://www.melon.com/chart/index.htm")

# %%
#상위 50
title_top=driver.find_elements_by_css_selector("#lst50 > td:nth-child(6) > div > div > div.ellipsis.rank01 > span > a")
artist_top=driver.find_elements_by_css_selector("#lst50 > td:nth-child(6) > div > div > div.ellipsis.rank02 > a")
album_top=driver.find_elements_by_css_selector("#lst50 > td:nth-child(4) > div > a > img")

# %%
# 상위 50 제목 가져오기 sample
#정규표현식 사용: re.findall("(.*) 재생",title_top[0].get_attribute("title"))
title_top[0].get_attribute("title").replace(" 재생", "")
# Out:
# 'ON'

# %%
# artist 가져오기 sample
artist_top[0].get_attribute("title").replace(" - 페이지 이동", "")
# Out:
# '방탄소년단'

# %%
# link 가져오기 sample
album_top=driver.find_elements_by_css_selector("#lst50 > td:nth-child(4) > div > a > img")
album_top[2].get_attribute("src")
# Out:
# 'https://cdnimg.melon.co.kr/cm2/album/images/103/88/744/10388744_20200214175740_500.jpg/melon/resize/120/quality/80/optimize'

# %%
top_50_list = []
bottom_50_list=[]


for index in range(50):
    title_top=driver.find_elements_by_css_selector("#lst50 > td:nth-child(6) > div > div > div.ellipsis.rank01 > span > a")
    title=title_top[index].get_attribute("title").replace(" 재생", "")
    
    artist_top=driver.find_elements_by_css_selector("#lst50 > td:nth-child(6) > div > div > div.ellipsis.rank02 > a")
    artist=artist_top[index].get_attribute("title").replace(" - 페이지 이동", "")
    
    album_top=driver.find_elements_by_css_selector("#lst50 > td:nth-child(4) > div > a > img")
    album_url=album_top[index].get_attribute("src")

    
    title_bottom1=driver.find_elements_by_css_selector("#lst100 > td:nth-child(6) > div > div > div.ellipsis.rank01 > span > a")
    title1=title_bottom1[index].get_attribute("title").replace(" 재생", "")
    
    artist_bottom1=driver.find_elements_by_css_selector("#lst100 > td:nth-child(6) > div > div > div.ellipsis.rank02 > a")
    artist1=artist_bottom1[index].get_attribute("title").replace(" - 페이지 이동", "")
    
    album_bottom1=driver.find_elements_by_css_selector("#lst100 > td:nth-child(4) > div > a > img")
    album_url1=album_bottom1[index].get_attribute("src")
    
    
    top_50_list.append({
        "title" : title,
        "artist" : artist,
        "album_url" : album_url
    })

    
    bottom_50_list.append({
        "title" : title1,
        "artist" : artist1,
        "album_url" : album_url1
    })

top50 = pd.DataFrame(top_50_list)
bottom50 = pd.DataFrame(bottom_50_list)
pd.concat([top50, bottom50], ignore_index=True)
# Out:
#                                             album_url             artist  \
# 0   https://cdnimg.melon.co.kr/cm2/album/images/10...              방탄소년단
# 1   https://cdnimg.melon.co.kr/cm2/album/images/10...          지코 (ZICO)
# 2   https://cdnimg.melon.co.kr/cm2/album/images/10...                아이유
# 3   https://cdnimg.melon.co.kr/cm2/album/images/10...              방탄소년단
# 4   https://cdnimg.melon.co.kr/cm2/album/images/10...              방탄소년단
# 5   https://cdnimg.melon.co.kr/cm2/album/images/10...              방탄소년단
# 6   https://cdnimg.melon.co.kr/cm2/album/images/10...              방탄소년단
# 7   https://cdnimg.melon.co.kr/cm2/album/images/10...              방탄소년단
# 8   https://cdnimg.melon.co.kr/cm2/album/images/10...              방탄소년단
# 9   https://cdnimg.melon.co.kr/cm/album/images/102...              방탄소년단
# 10  https://cdnimg.melon.co.kr/cm2/album/images/10...              방탄소년단
# 11  https://cdnimg.melon.co.kr/cm2/album/images/10...              방탄소년단
# ...
